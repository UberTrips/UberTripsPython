# %%
import pandas as pd

big = pd.read_csv('/Users/HudsonCavanagh/Desktop/big.csv')
big.head()
# Out:
#   Dispatching_base_num          Pickup_date    Borough             Zone  \
# 0               B02617  2015-05-17 09:47:00  Manhattan  Lenox Hill West
# 1               B02617  2015-05-17 09:50:00  Manhattan  Lenox Hill West
# 2               B02617  2015-05-17 09:53:00  Manhattan  Lenox Hill West
# 3               B02617  2015-05-17 10:00:00  Manhattan  Lenox Hill West
# 4               B02617  2015-05-17 10:00:00  Manhattan  Lenox Hill West
#
#    LocationID  dow  hour  month
# 0         141    6     9      5
# 1         141    6     9      5
# 2         141    6     9      5
# 3         141    6    10      5
# 4         141    6    10      5

# %%
small['uber_taxi_bin'].mean()
# Out:
# 0.7440476190476191

# %%
small['uber_prob'].mean()
# Out:
# 0.5581726006635952

# %%
small = pd.read_csv('/Users/HudsonCavanagh/GA_dsi-projects/UberTripPython/uber_app/non_uber_trips.csv')
small = small.iloc[:,1:]
small.columns = ['dow', 'hour', 'taxi-cs_avg_trips', 'uber_avg_trips','lyft_avg_trips', 'total_trips', 'uber_prob', 'uber_taxi_bin']
small
# Out:
#      weekday  hour  taxi-cs_avg_trips  uber_avg_trips  lyft_avg_trips  \
# 0          6     0                769            1458             323
# 1          6     1                645            1078             344
# 2          6     2                497             757             362
# 3          6     3                385             513             362
# 4          6     4                435             308             333
# 5          6     5                438             308             297
# 6          6     6                450             322             246
# 7          6     7                460             434             176
# 8          6     8                451             596              96
# 9          6     9                552             786              43
# 10         6    10                618             956              31
# 11         6    11                617            1109              38
# ...

# %%
small.columns
# Out:
# Index([u'dow', u'hour', u'taxi-cs_avg_trips', u'uber_avg_trips',
#        u'lyft_avg_trips', u'total_trips', u'uber_prob', u'uber_taxi_bin'],
#       dtype='object')

# %%
big['rides'] =1


test = big.groupby(['dow', 'hour']).sum()
test = test.drop(['month'], axis=1)
small.columns = ['dow', 'hour', 'taxi-cs_avg_trips', 'uber_avg_trips','lyft_avg_trips', 'total_trips', 'uber_prob', 'uber_taxi_bin']
small = small.groupby(['dow', 'hour']).sum()
final = pd.merge(test, small, how='left')
final.head()

# test.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-9776ee3540b3> in <module>()
#       5 test = big.groupby(['dow', 'hour']).sum()
#       6 test = test.drop(['month'], axis=1)
# ----> 7 small = small.groupby(['dow', 'hour']).sum()
#       8 final = pd.merge(test, small, how='left')
#       9 final.head()
#
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    3776         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    3777                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 3778                        **kwargs)
#    3779
#    3780     def asfreq(self, freq, method=None, how=None, normalize=False):
#
# ...

# %%
small = small.groupby(['dow', 'hour']).sum()
# Out:
#    weekday  hour  taxi-cs_avg_trips  uber_avg_trips  lyft_avg_trips  \
# 0        6     0                769            1458             323
# 1        6     1                645            1078             344
# 2        6     2                497             757             362
# 3        6     3                385             513             362
# 4        6     4                435             308             333
#
#    total_trips  uber_prob  uber_taxi_bin
# 0         2550   0.571765              1
# 1         2067   0.521529              1
# 2         1616   0.468441              0
# 3         1260   0.407143              0
# 4         1076   0.286245              0

# %%
final = pd.merge(test, small, left_on=['dow', 'hour'], right_on=['weekday', 'hour'], how='left')
final.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-abfdab931cf8> in <module>()
#       1
# ----> 2 final = pd.merge(test, small, left_on=['dow', 'hour'], right_on=['weekday', 'hour'], how='left')
#       3 final.head()
#
# /Users/HudsonCavanagh/anaconda/lib/python2.7/site-packages/pandas/tools/merge.pyc in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#      36                          right_on=right_on, left_index=left_index,
#      37                          right_index=right_index, sort=sort, suffixes=suffixes,
# ---> 38                          copy=copy, indicator=indicator)
#      39     return op.get_result()
#      40 if __debug__:
#
# ...

# %%
big['rides'][big['dow']==2].mean()
